# %% [markdown]
# <a href="https://colab.research.google.com/github/shivampathak2812/Exploratory-Data-Analysis/blob/main/EDA_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# !pip install pyxlsb

# %%
df1=pd.read_excel('/content/RAW DATA_sep_6.11.25.xlsb')

# %%
df1

# %%
shivam=pd.DataFrame(df1)

# %%
print(shivam)

# %%
shivam=df1['Courier Partner'].value_counts()

# %%
print(shivam)

# %%
shivam=pd.DataFrame(df1)

# %%
df.tail()

# %%
df.describe()

# %%
df.shape

# %%
df.describe(include='all')

# %%
df.info()

# %%
df.isnull().sum(axis=0)

# %%
df=df.isnull().sum()

# %%
df1['Courier Partner'].count()

# %%
print(shivam)

# %%
df.Courier_partner
